# %% [markdown]
# ## Objective
# Test stuff

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import pickle

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a simple plot
plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Plot')

# Save the plot and underlying data as a pickle file
with open('/data/MEAprojects/primary_mouse/tau/231111/22283/Network/000157/rt_sort/231227/output_plot.pkl', 'wb') as file:
    pickle.dump(plt.gcf(), file)

# Close the current figure
plt.close()

# Reopen the saved pickle file and display the plot
with open('/data/MEAprojects/primary_mouse/tau/231111/22283/Network/000157/rt_sort/231227/output_plot.pkl', 'rb') as file:
    loaded_fig = pickle.load(file)

plt.figure(loaded_fig.number)  # Activate the loaded 
plt.title("Test")
plt.show()
