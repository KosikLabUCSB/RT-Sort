# %% [markdown]
# ## Objective
# Create a bar plot showing the distribution of the number of waveforms in a sample

# %%
# %load_ext autoreload
# %autoreload

# Update PATH to allow imports
import sys
sys.path.append("/data/MEAprojects/DLSpikeSorter")

# Imports
import matplotlib.pyplot as plt
from pandas import DataFrame
from src.plot import set_dpi

# %%
# Plot
WFS_PROBS = [50, 30, 12, 6, 2]  # ith element is % prob of i waveforms appearing in sample
# set_dpi(400)
##
df = DataFrame(data={"Percents": WFS_PROBS}, index=range(len(WFS_PROBS)))
df.plot.bar(rot=0, linewidth=5)
plt.title("Number of Waveforms in Generated Samples Distribution")
plt.xlabel("Number of Waveforms")
plt.ylabel("Percent of Samples")
plt.show()
